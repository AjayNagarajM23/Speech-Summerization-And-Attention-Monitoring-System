# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('yolov5', 'custom', path='best.pt', force_reload=True , source='local')
# Out:
# fatal: cannot change to '/home/ajaynagarajm/Major': No such file or directory
# YOLOv5 🚀 2022-11-3 Python-3.11.2 torch-2.0.1+cu117 CUDA:0 (GeForce MX330, 2003MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76241736 parameters, 0 gradients, 110.2 GFLOPs
# Adding AutoShape...

# %%
img = 'Images/DSC_0006.JPG'
results = model(img,)
print(results)
# Out:
# image 1/1: 4000x6000 26 Focuseds, 2 NotFocuseds
# Speed: 243.1ms pre-process, 135.5ms inference, 1.0ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(1)
while True:
    ret, frame = cap.read()

    # Make detections
    results = model(frame)

    cv2.imshow('YOLO', np.squeeze(results.render()))

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
crops = results.crop(save=True, save_dir='Images/', hidelabels=True)

# %%
results.xywhn
# Out:
# [tensor([[ 0.29178,  0.66491,  0.04561,  0.08215,  0.96836, 15.00000],
#          [ 0.24910,  0.58928,  0.03996,  0.07991,  0.96043, 15.00000],
#          [ 0.30472,  0.57761,  0.03561,  0.07041,  0.95776, 15.00000],
#          [ 0.89065,  0.59988,  0.04346,  0.09205,  0.95707, 15.00000],
#          [ 0.74069,  0.64197,  0.03586,  0.08019,  0.95565, 15.00000],
#          [ 0.35856,  0.64919,  0.03978,  0.09505,  0.95417, 15.00000],
#          [ 0.39158,  0.55629,  0.03307,  0.06914,  0.95234, 15.00000],
#          [ 0.80316,  0.63704,  0.03867,  0.07867,  0.95129, 15.00000],
#          [ 0.84036,  0.59758,  0.04019,  0.07492,  0.95023, 15.00000],
#          [ 0.56669,  0.53186,  0.02998,  0.06770,  0.94853, 15.00000],
#          [ 0.42589,  0.61756,  0.03920,  0.07784,  0.94729, 15.00000],
#          [ 0.19751,  0.57933,  0.03946,  0.08007,  0.94626, 15.00000],
#          [ 0.65968,  0.63426,  0.03562,  0.07202,  0.94465, 15.00000],
# ...

# %%
! python yolov5/detect.py --weights best.pt --hide-labels --save-crop --source 'Images/DSC_0006.JPG'
# Out:
# detect: weights=['best.pt'], source=Images/DSC_0006.JPG, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=1, hide_labels=True, hide_conf=True, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/home/ajaynagarajm/Major': No such file or directory
# YOLOv5 🚀 2022-11-3 Python-3.10.7 torch-1.13.1+cpu CPU
#
# Fusing layers...
# Model summary: 346 layers, 76241736 parameters, 0 gradients, 110.2 GFLOPs
# image 1/1 /home/ajaynagarajm/Major Project/Images/DSC_0006.JPG: 448x640 26 Focuseds, 2 NotFocuseds, 888.0ms
# Speed: 62.3ms pre-process, 888.0ms inference, 111.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp2

# %%
from yolov5.detect import run

run(weights='best.pt', 
    hide_labels=True, 
    save_crop=True, 
    source=img, 
    name='Images', 
    project='')
# Out:
# fatal: cannot change to '/home/ajaynagarajm/Major': No such file or directory
# YOLOv5 🚀 2022-11-3 Python-3.11.2 torch-2.0.1+cu117 CUDA:0 (GeForce MX330, 2003MiB)
#
# Fusing layers...
# Model summary: 346 layers, 76241736 parameters, 0 gradients, 110.2 GFLOPs
# image 1/1 /home/ajaynagarajm/Major Project/Images/test_final.png: 384x640 5 Focuseds, 111.2ms
# Speed: 1.0ms pre-process, 111.2ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to Images2

# %%
# image = cv2.imread("Images/test_final.png", cv2.IMREAD_COLOR)
# kernel = np.array([[0, -1, 0],
#                    [-1, 5,-1],
#                    [0, -1, 0]])
# image_sharp = cv2.filter2D(src=image, ddepth=-1, kernel=kernel)
# cv2.imshow('AV CV- Winter Wonder Sharpened', image_sharp)
# cv2.waitKey()
# cv2.destroyAllWindows()

# %%
# cv2.imwrite('enhancedimg.jpg',image_sharp)
# Out:
# True
